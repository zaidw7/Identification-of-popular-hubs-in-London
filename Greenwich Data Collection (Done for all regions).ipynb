# %%
import pandas as pd
from pandas import DataFrame as df
import numpy as np
import time

# %%
a = pd.read_csv('art_gallery (1).csv')
a = a.append(pd.read_csv('art_gallery.csv'))
a = a.append(pd.read_csv('bar (1).csv'))
a = a.append(pd.read_csv('bar (2).csv'))
a = a.append(pd.read_csv('bar.csv'))
a = a.append(pd.read_csv('book_store (1).csv'))
a = a.append(pd.read_csv('book_store.csv'))
a = a.append(pd.read_csv('bowling_alley.csv'))
a = a.append(pd.read_csv('café (1).csv'))
a = a.append(pd.read_csv('café (2).csv'))
a = a.append(pd.read_csv('café.csv'))
a = a.append(pd.read_csv('casino.csv'))
a = a.append(pd.read_csv('clothing_store (1).csv'))
a = a.append(pd.read_csv('clothing_store (2).csv'))
a = a.append(pd.read_csv('clothing_store.csv'))
a = a.append(pd.read_csv('health (1).csv'))
a = a.append(pd.read_csv('health (2).csv'))
a = a.append(pd.read_csv('health.csv'))
a = a.append(pd.read_csv('Iconic Places (1).csv'))
a = a.append(pd.read_csv('Iconic Places (2).csv'))
a = a.append(pd.read_csv('Iconic Places (3).csv'))
a = a.append(pd.read_csv('library.csv'))
a = a.append(pd.read_csv('lodging (1).csv'))
a = a.append(pd.read_csv('lodging (2).csv'))
a = a.append(pd.read_csv('lodging.csv'))
a = a.append(pd.read_csv('movie_theater.csv'))
a = a.append(pd.read_csv('museum (1).csv'))
a = a.append(pd.read_csv('museum.csv'))
a = a.append(pd.read_csv('night_club.csv'))
a = a.append(pd.read_csv('park (1).csv'))
a = a.append(pd.read_csv('park (2).csv'))
a = a.append(pd.read_csv('park.csv'))
a = a.append(pd.read_csv('point_of_interest (1).csv'))
a = a.append(pd.read_csv('point_of_interest (2).csv'))
a = a.append(pd.read_csv('point_of_interest.csv'))
a = a.append(pd.read_csv('restaurant (1).csv'))
a = a.append(pd.read_csv('restaurant (2).csv'))
a = a.append(pd.read_csv('restaurant.csv'))
a = a.append(pd.read_csv('tourist_attraction (1).csv'))
a = a.append(pd.read_csv('tourist_attraction (2).csv'))
a = a.append(pd.read_csv('tourist_attraction.csv'))
a = a.append(pd.read_csv('zoo.csv'))

a = a.drop_duplicates()
a.reset_index(drop=True, inplace=True)

# %%
a
# Out:
#                              name  \
# 0               Made in Greenwich
# 1              Ben Oakley Gallery
# 2          Maria's Parallel World
# 3              AddictedToMuse Ltd
# 4               White Box Gallery
# ..                            ...
# 709                     Pig House
# 710                  Tamworth Pig
# 711              ELTHAM HEN HOUSE
# 712                    Dog's Park
# 713  Greenwich Peninsula Wildlife
#
#                                               vicinity       type/0  \
# 0                               324 Creek Road, London  art_gallery
# 1             9 Greenwich Market, Turnpin Lane, London  art_gallery
# 2                          5B Greenwich Market, London  art_gallery
# 3                             Christchurch Way, London  art_gallery
# 4                       5 Hare and Billet Road, London  art_gallery
# ..                                                 ...          ...
# 709                                    FXRQ+9C, London          zoo
# ...

# %%
a.to_csv('Greenwich.csv')
